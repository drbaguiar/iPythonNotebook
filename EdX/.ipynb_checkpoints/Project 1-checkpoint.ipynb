# %%
import graphlab

# %%
sf = graphlab.SFrame('gapminder.csv')
# Out:
# [INFO] This non-commercial license of GraphLab Create is assigned to drbaguiar@gmail.comand will expire on October 15, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-17360 - Server binary: C:\Users\bryan_000\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\BRYAN_~1\AppData\Local\Temp\graphlab_server_1445032745.log.0
# [INFO] GraphLab Server Version: 1.6.1
# PROGRESS: Finished parsing file C:\Users\bryan_000\Documents\GitHub\iPythonNotebook\EdX\gapminder.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.055039 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[str,float,str,str,str,str,str,str,str,float,float,long,str,float,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# ...

# %%
sf
# Out:
# Columns:
# 	country	str
# 	incomeperperson	float
# 	alcconsumption	str
# 	armedforcesrate	str
# 	breastcancerper100th	str
# 	co2emissions	str
# 	femaleemployrate	str
# 	hivrate	str
# 	internetuserate	str
# 	lifeexpectancy	float
# 	oilperperson	float
# 	polityscore	int
# 	relectricperperson	str
# 	suicideper100th	float
# 	employrate	str
# 	urbanrate	str
#
# Rows: 213
#
# Data:
# +---------------------+-----------------+----------------+-----------------+
# |       country       | incomeperperson | alcconsumption | armedforcesrate |
# +---------------------+-----------------+----------------+-----------------+
# |     Afghanistan     |       None      |      .03       |     .5696534    |
# |       Albania       |  1914.99655095  |      7.29      |    1.0247361    |
# |       Algeria       |  2231.99333515  |      .69       |     2.306817    |
# |       Andorra       |  21943.3398976  |     10.17      |                 |
# ...

# %%
graphlab.canvas.set_target('ipynb')
sf.show(view="Scatter Plot", x="internetuserate", y="suicideper100th")

# %%
train_data,test_data = sf.random_split(.8,seed=0)

# %%
train_data
# Out:
# Columns:
# 	country	str
# 	incomeperperson	float
# 	alcconsumption	str
# 	armedforcesrate	str
# 	breastcancerper100th	str
# 	co2emissions	str
# 	femaleemployrate	str
# 	hivrate	str
# 	internetuserate	str
# 	lifeexpectancy	float
# 	oilperperson	float
# 	polityscore	int
# 	relectricperperson	str
# 	suicideper100th	float
# 	employrate	str
# 	urbanrate	str
#
# Rows: Unknown
#
# Data:
# +---------------------+-----------------+----------------+-----------------+
# |       country       | incomeperperson | alcconsumption | armedforcesrate |
# +---------------------+-----------------+----------------+-----------------+
# |     Afghanistan     |       None      |      .03       |     .5696534    |
# |       Albania       |  1914.99655095  |      7.29      |    1.0247361    |
# |       Algeria       |  2231.99333515  |      .69       |     2.306817    |
# |       Andorra       |  21943.3398976  |     10.17      |                 |
# ...

# %%
model = graphlab.linear_regression.create(train_data, target='suicideper100th', features=['internetuserate'],validation_set=None)
# Out:
# [ERROR] Toolkit error: Target column has missing value.                    Please use dropna() to drop rows with missing target values.
# ---------------------------------------------------------------------------
# ToolkitError                              Traceback (most recent call last)
# <ipython-input-21-dd8b903a1b32> in <module>()
# ----> 1 model = graphlab.linear_regression.create(train_data, target='suicideper100th', features=['internetuserate'],validation_set=None)
#
# C:\Users\bryan_000\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\toolkits\regression\linear_regression.pyc in create(dataset, target, features, l2_penalty, l1_penalty, solver, feature_rescaling, convergence_threshold, step_size, lbfgs_memory_level, max_iterations, validation_set, verbose)
#     278                         step_size = step_size,
#     279                         lbfgs_memory_level = lbfgs_memory_level,
# --> 280                         max_iterations = max_iterations)
#     281
# ...
